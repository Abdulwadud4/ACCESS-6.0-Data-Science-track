# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulwadud4/ACCESS-6.0-Data-Science-track/blob/main/assignment_week_2_session_4_data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
wh = pd.read_csv("/content/Warehouse_and_Retail_Sales (1).csv")

# %%
wh
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                        LEGENDS LTD     99753
# 307641  2020      9                 ANHEUSER BUSCH INC      9997
# 307642  2020      9        COASTAL BREWING COMPANY LLC     99970
# 307643  2020      9            BOSTON BEER CORPORATION     99990
# 307644  2020      9                                NaN        WC
#
#                                ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                           BOOTLEG RED - 750ML      WINE          0.00
# ...

# %%
wh.head(10)
# Out:
#    YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0  2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1  2020      1                          PWSWN INC    100024
# 2  2020      1            RELIABLE CHURCHILL LLLP      1001
# 3  2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4  2020      1               DIONYSOS IMPORTS INC    100293
# 5  2020      1            KYSELA PERE ET FILS LTD    100641
# 6  2020      1           SANTA MARGHERITA USA INC    100749
# 7  2020      1   BROWN-FORMAN BEVERAGES WORLDWIDE      1008
# 8  2020      1                 JIM BEAM BRANDS CO     10103
# 9  2020      1          INTERNATIONAL CELLARS LLC    101117
#
#                                     ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                                BOOTLEG RED - 750ML      WINE          0.00
# 1                          MOMENT DE PLAISIR - 750ML      WINE          0.00
# ...

# %%
wh.isnull().sum()
# Out:
# YEAR                  0
# MONTH                 0
# SUPPLIER            167
# ITEM CODE             0
# ITEM DESCRIPTION      0
# ITEM TYPE             1
# RETAIL SALES          3
# RETAIL TRANSFERS      0
# WAREHOUSE SALES       0
# dtype: int64

# %%
wh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307645 entries, 0 to 307644
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   YEAR              307645 non-null  int64
#  1   MONTH             307645 non-null  int64
#  2   SUPPLIER          307478 non-null  object
#  3   ITEM CODE         307645 non-null  object
#  4   ITEM DESCRIPTION  307645 non-null  object
#  5   ITEM TYPE         307644 non-null  object
#  6   RETAIL SALES      307642 non-null  float64
#  7   RETAIL TRANSFERS  307645 non-null  float64
#  8   WAREHOUSE SALES   307645 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 21.1+ MB

# %%
wh = wh.dropna(subset=["SUPPLIER"])
wh = wh.dropna(subset = ["ITEM TYPE"])
wh = wh.dropna(subset=["RETAIL SALES"])

# %%
wh.isnull().sum()
# Out:
# YEAR                0
# MONTH               0
# SUPPLIER            0
# ITEM CODE           0
# ITEM DESCRIPTION    0
# ITEM TYPE           0
# RETAIL SALES        0
# RETAIL TRANSFERS    0
# WAREHOUSE SALES     0
# dtype: int64

# %%
wh.duplicated().sum()
# Out:
# np.int64(0)

# %%
wh.describe()
# Out:
#                 YEAR          MONTH   RETAIL SALES  RETAIL TRANSFERS  \
# count  307477.000000  307477.000000  307477.000000     307477.000000
# mean     2018.438238       6.424064       7.003644          6.938177
# std         1.083080       3.461853      30.387012         30.244239
# min      2017.000000       1.000000      -6.490000        -38.490000
# 25%      2017.000000       3.000000       0.000000          0.000000
# 50%      2019.000000       7.000000       0.320000          0.000000
# 75%      2019.000000       9.000000       3.260000          3.000000
# max      2020.000000      12.000000    1816.490000       1990.830000
#
#        WAREHOUSE SALES
# count    307477.000000
# mean         25.375561
# std         249.500572
# min       -4996.000000
# 25%           0.000000
# 50%           1.000000
# 75%           5.000000
# max       18317.000000

# %%
import pandas as pd
import numpy as np
wh = pd.read_csv("/content/Warehouse_and_Retail_Sales (1).csv")

# %%
wh.head(10)
# Out:
#    YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0  2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1  2020      1                          PWSWN INC    100024
# 2  2020      1            RELIABLE CHURCHILL LLLP      1001
# 3  2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4  2020      1               DIONYSOS IMPORTS INC    100293
# 5  2020      1            KYSELA PERE ET FILS LTD    100641
# 6  2020      1           SANTA MARGHERITA USA INC    100749
# 7  2020      1   BROWN-FORMAN BEVERAGES WORLDWIDE      1008
# 8  2020      1                 JIM BEAM BRANDS CO     10103
# 9  2020      1          INTERNATIONAL CELLARS LLC    101117
#
#                                     ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                                BOOTLEG RED - 750ML      WINE          0.00
# 1                          MOMENT DE PLAISIR - 750ML      WINE          0.00
# ...

# %%
wh.tail(10)
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 307635  2020      9  REPUBLIC NATIONAL DISTRIBUTING CO     99694
# 307636  2020      9           SIERRA NEVADA BREWING CO     99708
# 307637  2020      9           SIERRA NEVADA BREWING CO     99716
# 307638  2020      9                        LEGENDS LTD     99730
# 307639  2020      9             MILLER BREWING COMPANY     99740
# 307640  2020      9                        LEGENDS LTD     99753
# 307641  2020      9                 ANHEUSER BUSCH INC      9997
# 307642  2020      9        COASTAL BREWING COMPANY LLC     99970
# 307643  2020      9            BOSTON BEER CORPORATION     99990
# 307644  2020      9                                NaN        WC
#
#                                 ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 307635           PAULANER SALVATORE 4/6NR - 12OZ      BEER          0.25
# 307636     SIERRA NEVADA PALE ALE 2/12 NR - 12OZ      BEER         35.00
# ...

# %%
wh.isnull().sum()
# Out:
# YEAR                  0
# MONTH                 0
# SUPPLIER            167
# ITEM CODE             0
# ITEM DESCRIPTION      0
# ITEM TYPE             1
# RETAIL SALES          3
# RETAIL TRANSFERS      0
# WAREHOUSE SALES       0
# dtype: int64

# %%
wh = wh.dropna(subset=["SUPPLIER"])
wh = wh.dropna(subset = ["ITEM TYPE"])
wh = wh.dropna(subset = ["RETAIL SALES"])

# %%
wh.isnull().sum()
# Out:
# YEAR                0
# MONTH               0
# SUPPLIER            0
# ITEM CODE           0
# ITEM DESCRIPTION    0
# ITEM TYPE           0
# RETAIL SALES        0
# RETAIL TRANSFERS    0
# WAREHOUSE SALES     0
# dtype: int64

# %%
wh.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 307639    False
# 307640    False
# 307641    False
# 307642    False
# 307643    False
# Length: 307477, dtype: bool

# %%
wh.duplicated().sum()
# Out:
# np.int64(0)

# %%
wh.to_csv("warehouse_cleaned.csv")

# %%
wh.tail(10)
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 307634  2020      9                        LEGENDS LTD     99684
# 307635  2020      9  REPUBLIC NATIONAL DISTRIBUTING CO     99694
# 307636  2020      9           SIERRA NEVADA BREWING CO     99708
# 307637  2020      9           SIERRA NEVADA BREWING CO     99716
# 307638  2020      9                        LEGENDS LTD     99730
# 307639  2020      9             MILLER BREWING COMPANY     99740
# 307640  2020      9                        LEGENDS LTD     99753
# 307641  2020      9                 ANHEUSER BUSCH INC      9997
# 307642  2020      9        COASTAL BREWING COMPANY LLC     99970
# 307643  2020      9            BOSTON BEER CORPORATION     99990
#
#                                 ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 307634           DANSK VIKING BLOOD MEAD - 750ML      WINE          1.69
# 307635           PAULANER SALVATORE 4/6NR - 12OZ      BEER          0.25
# ...

# %%
wh.describe()
# Out:
#                 YEAR          MONTH   RETAIL SALES  RETAIL TRANSFERS  \
# count  307477.000000  307477.000000  307477.000000     307477.000000
# mean     2018.438238       6.424064       7.003644          6.938177
# std         1.083080       3.461853      30.387012         30.244239
# min      2017.000000       1.000000      -6.490000        -38.490000
# 25%      2017.000000       3.000000       0.000000          0.000000
# 50%      2019.000000       7.000000       0.320000          0.000000
# 75%      2019.000000       9.000000       3.260000          3.000000
# max      2020.000000      12.000000    1816.490000       1990.830000
#
#        WAREHOUSE SALES
# count    307477.000000
# mean         25.375561
# std         249.500572
# min       -4996.000000
# 25%           0.000000
# 50%           1.000000
# 75%           5.000000
# max       18317.000000

# %%
wh.columns.to_list()
# Out:
# ['YEAR',
#  'MONTH',
#  'SUPPLIER',
#  'ITEM CODE',
#  'ITEM DESCRIPTION',
#  'ITEM TYPE',
#  'RETAIL SALES',
#  'RETAIL TRANSFERS',
#  'WAREHOUSE SALES']

# %%
wh["MONTH"].value_counts()
# Out:
# MONTH
# 1     37700
# 9     37358
# 7     36688
# 11    27368
# 10    26698
# 8     25991
# 6     25945
# 2     25378
# 3     24188
# 12    14497
# 5     12940
# 4     12726
# Name: count, dtype: int64

# %%
MONTH_mapping = {"1" : "january" , "2" : "february" , "3" : "march" , "4" : "april" ,
                 "5" : "may" , "6" : "june" , "7" : "july" , "8" : "august" , "9" : "sepyember" ,
                 "10" : "october" , "11" : "november" , "12" : "december"}

# %%
wh["MONTH"] = wh["MONTH"].replace(MONTH_mapping)

# %%
wh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 307477 entries, 0 to 307643
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   YEAR              307477 non-null  int64
#  1   MONTH             307477 non-null  int64
#  2   SUPPLIER          307477 non-null  object
#  3   ITEM CODE         307477 non-null  object
#  4   ITEM DESCRIPTION  307477 non-null  object
#  5   ITEM TYPE         307477 non-null  object
#  6   RETAIL SALES      307477 non-null  float64
#  7   RETAIL TRANSFERS  307477 non-null  float64
#  8   WAREHOUSE SALES   307477 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 23.5+ MB

# %%
df["MONTH"]=pd.to_datetime(df["MONTH"], format = "%m").dt.month_name()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1678040252.py in <cell line: 0>()
# ----> 1 df["MONTH"]=pd.to_datetime(df["MONTH"], format = "%m").dt.month_name()
#
# NameError: name 'df' is not defined
